# %% [markdown]
# <a href="https://colab.research.google.com/github/agterzis/ADK-AI-Agent/blob/main/Agent_Architectures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-adk==1.18.0
# Out:
# Collecting google-adk==1.18.0
#   Downloading google_adk-1.18.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: PyYAML<7.0.0,>=6.0.2 in /usr/local/lib/python3.12/dist-packages (from google-adk==1.18.0) (6.0.3)
# Requirement already satisfied: anyio<5.0.0,>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from google-adk==1.18.0) (4.11.0)
# Requirement already satisfied: authlib<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from google-adk==1.18.0) (1.6.5)
# Requirement already satisfied: click<9.0.0,>=8.1.8 in /usr/local/lib/python3.12/dist-packages (from google-adk==1.18.0) (8.3.0)
# Requirement already satisfied: fastapi<1.119.0,>=0.115.0 in /usr/local/lib/python3.12/dist-packages (from google-adk==1.18.0) (0.121.1)
# Requirement already satisfied: google-api-python-client<3.0.0,>=2.157.0 in /usr/local/lib/python3.12/dist-packages (from google-adk==1.18.0) (2.187.0)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.125.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk==1.18.0) (1.126.1)
# Requirement already satisfied: google-cloud-bigtable>=2.32.0 in /usr/local/lib/python3.12/dist-packages (from google-adk==1.18.0) (2.34.0)
# Requirement already satisfied: google-cloud-discoveryengine<0.14.0,>=0.13.12 in /usr/local/lib/python3.12/dist-packages (from google-adk==1.18.0) (0.13.12)
# Requirement already satisfied: google-cloud-secret-manager<3.0.0,>=2.22.0 in /usr/local/lib/python3.12/dist-packages (from google-adk==1.18.0) (2.25.0)
# Requirement already satisfied: google-cloud-spanner<4.0.0,>=3.56.0 in /usr/local/lib/python3.12/dist-packages (from google-adk==1.18.0) (3.59.0)
# Requirement already satisfied: google-cloud-speech<3.0.0,>=2.30.0 in /usr/local/lib/python3.12/dist-packages (from google-adk==1.18.0) (2.34.0)
# Collecting google-cloud-storage<4.0.0,>=3.0.0 (from google-adk==1.18.0)
#   Downloading google_cloud_storage-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: google-genai<2.0.0,>=1.45.0 in /usr/local/lib/python3.12/dist-packages (from google-adk==1.18.0) (1.49.0)
# Requirement already satisfied: graphviz<1.0.0,>=0.20.2 in /usr/local/lib/python3.12/dist-packages (from google-adk==1.18.0) (0.21)
# Requirement already satisfied: mcp<2.0.0,>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from google-adk==1.18.0) (1.21.0)
# Requirement already satisfied: opentelemetry-api<=1.37.0,>=1.37.0 in /usr/local/lib/python3.12/dist-packages (from google-adk==1.18.0) (1.37.0)
# Requirement already satisfied: opentelemetry-exporter-gcp-logging<2.0.0,>=1.9.0a0 in /usr/local/lib/python3.12/dist-packages (from google-adk==1.18.0) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0 in /usr/local/lib/python3.12/dist-packages (from google-adk==1.18.0) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-trace<2.0.0,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from google-adk==1.18.0) (1.11.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.36.0 in /usr/local/lib/python3.12/dist-packages (from google-adk==1.18.0) (1.37.0)
# Requirement already satisfied: opentelemetry-resourcedetector-gcp<2.0.0,>=1.9.0a0 in /usr/local/lib/python3.12/dist-packages (from google-adk==1.18.0) (1.11.0a0)
# Requirement already satisfied: opentelemetry-sdk<=1.37.0,>=1.37.0 in /usr/local/lib/python3.12/dist-packages (from google-adk==1.18.0) (1.37.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from google-adk==1.18.0) (2.11.10)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0.post0 in /usr/local/lib/python3.12/dist-packages (from google-adk==1.18.0) (2.9.0.post0)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from google-adk==1.18.0) (1.2.1)
# Requirement already satisfied: requests<3.0.0,>=2.32.4 in /usr/local/lib/python3.12/dist-packages (from google-adk==1.18.0) (2.32.4)
# Requirement already satisfied: sqlalchemy-spanner>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from google-adk==1.18.0) (1.17.1)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from google-adk==1.18.0) (2.0.44)
# Requirement already satisfied: starlette<1.0.0,>=0.46.2 in /usr/local/lib/python3.12/dist-packages (from google-adk==1.18.0) (0.49.3)
# Collecting tenacity<10.0.0,>=9.0.0 (from google-adk==1.18.0)
#   Downloading tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: typing-extensions<5,>=4.5 in /usr/local/lib/python3.12/dist-packages (from google-adk==1.18.0) (4.15.0)
# Requirement already satisfied: tzlocal<6.0,>=5.3 in /usr/local/lib/python3.12/dist-packages (from google-adk==1.18.0) (5.3.1)
# Requirement already satisfied: uvicorn<1.0.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from google-adk==1.18.0) (0.38.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from google-adk==1.18.0) (6.0.0)
# Requirement already satisfied: websockets<16.0.0,>=15.0.1 in /usr/local/lib/python3.12/dist-packages (from google-adk==1.18.0) (15.0.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.9.0->google-adk==1.18.0) (3.11)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.9.0->google-adk==1.18.0) (1.3.1)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.12/dist-packages (from authlib<2.0.0,>=1.5.1->google-adk==1.18.0) (43.0.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.119.0,>=0.115.0->google-adk==1.18.0) (0.0.4)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk==1.18.0) (0.31.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk==1.18.0) (2.38.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk==1.18.0) (0.2.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk==1.18.0) (2.28.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk==1.18.0) (4.2.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk==1.18.0) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk==1.18.0) (5.29.5)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk==1.18.0) (25.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk==1.18.0) (3.38.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk==1.18.0) (1.15.0)
# Requirement already satisfied: shapely<3.0.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk==1.18.0) (2.1.2)
# Requirement already satisfied: docstring_parser<1 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk==1.18.0) (0.17.0)
# Requirement already satisfied: cloudpickle<4.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk==1.18.0) (3.1.2)
# Requirement already satisfied: google-cloud-trace<2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk==1.18.0) (1.17.0)
# Requirement already satisfied: google-cloud-logging<4 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk==1.18.0) (3.12.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=1.4.4 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigtable>=2.32.0->google-adk==1.18.0) (2.5.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigtable>=2.32.0->google-adk==1.18.0) (0.14.3)
# Requirement already satisfied: google-crc32c<2.0.0dev,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigtable>=2.32.0->google-adk==1.18.0) (1.7.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-secret-manager<3.0.0,>=2.22.0->google-adk==1.18.0) (1.76.0)
# Requirement already satisfied: sqlparse>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk==1.18.0) (0.5.3)
# Requirement already satisfied: grpc-interceptor>=0.15.4 in /usr/local/lib/python3.12/dist-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk==1.18.0) (0.15.4)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage<4.0.0,>=3.0.0->google-adk==1.18.0) (2.7.2)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.45.0->google-adk==1.18.0) (0.28.1)
# Requirement already satisfied: httpx-sse>=0.4 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0.0,>=1.8.0->google-adk==1.18.0) (0.4.3)
# Requirement already satisfied: jsonschema>=4.20.0 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0.0,>=1.8.0->google-adk==1.18.0) (4.25.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0.0,>=1.8.0->google-adk==1.18.0) (2.12.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.8.0->google-adk==1.18.0) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0.0,>=1.8.0->google-adk==1.18.0) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0.0,>=1.8.0->google-adk==1.18.0) (3.0.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api<=1.37.0,>=1.37.0->google-adk==1.18.0) (8.7.0)
# Requirement already satisfied: google-cloud-monitoring~=2.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0->google-adk==1.18.0) (2.28.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk==1.18.0) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk==1.18.0) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk==1.18.0) (1.37.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk<=1.37.0,>=1.37.0->google-adk==1.18.0) (0.58b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0->google-adk==1.18.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0->google-adk==1.18.0) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0->google-adk==1.18.0) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.9.0.post0->google-adk==1.18.0) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.4->google-adk==1.18.0) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.4->google-adk==1.18.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.4->google-adk==1.18.0) (2025.10.5)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy<3.0.0,>=2.0->google-adk==1.18.0) (3.2.4)
# Requirement already satisfied: alembic in /usr/local/lib/python3.12/dist-packages (from sqlalchemy-spanner>=1.14.0->google-adk==1.18.0) (1.17.1)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn<1.0.0,>=0.34.0->google-adk==1.18.0) (0.16.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk==1.18.0) (1.71.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk==1.18.0) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk==1.18.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk==1.18.0) (4.9.1)
# Requirement already satisfied: google-cloud-appengine-logging<2.0.0,>=0.1.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk==1.18.0) (1.7.0)
# Requirement already satisfied: google-cloud-audit-log<1.0.0,>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk==1.18.0) (0.4.0)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in /usr/local/lib/python3.12/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client<3.0.0,>=2.157.0->google-adk==1.18.0) (3.2.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.45.0->google-adk==1.18.0) (1.0.9)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<=1.37.0,>=1.37.0->google-adk==1.18.0) (3.23.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk==1.18.0) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk==1.18.0) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk==1.18.0) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk==1.18.0) (0.28.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography->authlib<2.0.0,>=1.5.1->google-adk==1.18.0) (2.0.0)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.12/dist-packages (from shapely<3.0.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk==1.18.0) (2.0.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic->sqlalchemy-spanner>=1.14.0->google-adk==1.18.0) (1.3.10)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography->authlib<2.0.0,>=1.5.1->google-adk==1.18.0) (2.23)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk==1.18.0) (0.6.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic->sqlalchemy-spanner>=1.14.0->google-adk==1.18.0) (3.0.3)
# Downloading google_adk-1.18.0-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 31.1 MB/s eta 0:00:00
# Downloading google_cloud_storage-3.5.0-py3-none-any.whl (289 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.0/290.0 kB 17.8 MB/s eta 0:00:00
# Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Installing collected packages: tenacity, google-cloud-storage, google-adk
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.5.0
#     Uninstalling tenacity-8.5.0:
#       Successfully uninstalled tenacity-8.5.0
#   Attempting uninstall: google-cloud-storage
#     Found existing installation: google-cloud-storage 2.19.0
#     Uninstalling google-cloud-storage-2.19.0:
#       Successfully uninstalled google-cloud-storage-2.19.0
#   Attempting uninstall: google-adk
#     Found existing installation: google-adk 1.17.0
#     Uninstalling google-adk-1.17.0:
#       Successfully uninstalled google-adk-1.17.0
# Successfully installed google-adk-1.18.0 google-cloud-storage-3.5.0 tenacity-9.1.2

# %%
import os
from google.colab import userdata
import google.generativeai as genai

try:
    GOOGLE_API_KEY = userdata.get("GOOGLE_API_KEY")
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY # Set as environment variable
    genai.configure(api_key=GOOGLE_API_KEY) # Configure google.generativeai globally
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print(
        f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Colab secrets. Details: {e}"
    )
# Out:
# ✅ Gemini API key setup complete.

# %%
from google.adk.agents import Agent, SequentialAgent, ParallelAgent, LoopAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504], # Retry on these HTTP errors
)

# %% [markdown]
# Research Agent - Searches for information using Google Search
# Summarizer Agent - Creates concise summaries from research findings

# %%
# Research Agent: Its job is to use the google_search tool and present findings.
research_agent = Agent(
    name="ResearchAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a specialized research agent. Your only job is to use the
    google_search tool to find 2-3 pieces of relevant information on the given topic and present the findings with citations.""",
    tools=[google_search],
    output_key="research_findings",  # The result of this agent will be stored in the session state with this key.
)

print("✅ research_agent created.")
# Out:
# ✅ research_agent created.

# %%
# Summarizer Agent: Its job is to summarize the text it receives.
summarizer_agent = Agent(
    name="SummarizerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The instruction is modified to request a bulleted list for a clear output format.
    instruction="""Read the provided research findings: {research_findings}
Create a concise summary as a bulleted list with 3-5 key points.""",
    output_key="final_summary",
)

print("✅ summarizer_agent created.")
# Out:
# ✅ summarizer_agent created.

# %%
# Root Coordinator: Orchestrates the workflow by calling the sub-agents as tools.
root_agent = Agent(
    name="ResearchCoordinator",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This instruction tells the root agent HOW to use its tools (which are the other agents).
    instruction="""You are a research coordinator. Your goal is to answer the user's query by orchestrating a workflow.
1. First, you MUST call the `ResearchAgent` tool to find relevant information on the topic provided by the user.
2. Next, after receiving the research findings, you MUST call the `SummarizerAgent` tool to create a concise summary.
3. Finally, present the final summary clearly to the user as your response.""",
    # We wrap the sub-agents in `AgentTool` to make them callable tools for the root agent.
    tools=[AgentTool(research_agent), AgentTool(summarizer_agent)],
)

print("✅ root_agent created.")
# Out:
# ✅ root_agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "What are the latest advancements in quantum computing and what do they mean for AI?"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > What are the latest advancements in quantum computing and what do they mean for AI?
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# ResearchCoordinator > Quantum computing advancements are poised to revolutionize AI by offering exponential processing power, overcoming current limitations in deep learning and optimization. Key developments in Quantum Machine Learning (QML) are creating more efficient and scalable algorithms. The implications for AI include significantly boosted performance, the ability to tackle previously intractable problems, enhanced optimization capabilities, and improvements in specific applications like natural language processing and autonomous vehicles. Major technology companies are investing heavily in this field, and while fully fault-tolerant quantum hardware is still in development, the synergy between quantum computing and AI is expected to redefine future technological landscapes.

# %%
# Outline Agent: Creates the initial blog post outline.
outline_agent = Agent(
    name="OutlineAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Create a blog outline for the given topic with:
    1. A catchy headline
    2. An introduction hook
    3. 3-5 main sections with 2-3 bullet points for each
    4. A concluding thought""",
    output_key="blog_outline",  # The result of this agent will be stored in the session state with this key.
)

print("✅ outline_agent created.")
# Out:
# ✅ outline_agent created.

# %%
# Writer Agent: Writes the full blog post based on the outline from the previous agent.
writer_agent = Agent(
    name="WriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The `{blog_outline}` placeholder automatically injects the state value from the previous agent's output.
    instruction="""Following this outline strictly: {blog_outline}
    Write a brief, 200 to 300-word blog post with an engaging and informative tone.""",
    output_key="blog_draft",  # The result of this agent will be stored with this key.
)

print("✅ writer_agent created.")
# Out:
# ✅ writer_agent created.

# %%
# Editor Agent: Edits and polishes the draft from the writer agent.
editor_agent = Agent(
    name="EditorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This agent receives the `{blog_draft}` from the writer agent's output.
    instruction="""Edit this draft: {blog_draft}
    Your task is to polish the text by fixing any grammatical errors, improving the flow and sentence structure, and enhancing overall clarity.""",
    output_key="final_blog",  # This is the final output of the entire pipeline.
)

print("✅ editor_agent created.")
# Out:
# ✅ editor_agent created.

# %%
root_agent = SequentialAgent(
    name="BlogPipeline",
    sub_agents=[outline_agent, writer_agent, editor_agent],
)

print("✅ Sequential Agent created.")
# Out:
# ✅ Sequential Agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a blog post about the benefits of multi-agent systems for software developers"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a blog post about the benefits of multi-agent systems for software developers
# OutlineAgent > ## Outline:
#
# **Headline:** Supercharge Your Code: How Multi-Agent Systems Will Revolutionize Software Development
#
# **Introduction Hook:** Ever feel like your software projects are battling complexity, not conquering it? What if you could harness the power of a distributed team of intelligent "assistants" to streamline your development process, catch bugs before they hatch, and even write better code? Enter Multi-Agent Systems (MAS), a paradigm shift that's poised to redefine how we build software.
#
# ### Section 1: What Exactly is a Multi-Agent System?
#
# *   **Defining the "Agents":** Explain that MAS involves multiple independent software entities (agents) that interact with each other and their environment to achieve individual or collective goals.
# *   **Beyond Traditional Software:** Contrast MAS with monolithic applications, highlighting the benefits of modularity, autonomy, and emergent behavior.
# *   **Real-World Examples (Brief):** Touch upon existing MAS applications (e.g., robotics, simulations, smart grids) to illustrate the concept's power.
#
# ### Section 2: The Developer's New Best Friends: Key Benefits of MAS
#
# *   **Enhanced Problem Solving & Complexity Management:**
#     *   Break down large, complex problems into smaller, manageable sub-tasks handled by specialized agents.
#     *   Achieve more robust solutions through the combined intelligence and diverse perspectives of multiple agents.
# *   **Improved Efficiency & Automation:**
#     *   Automate repetitive coding tasks, testing, and debugging processes, freeing up developers for more creative work.
#     *   Enable continuous integration and deployment (CI/CD) workflows with agents monitoring and acting on code changes.
# *   **Intelligent Code Assistance & Quality Assurance:**
#     *   Agents can act as "super-linters" or "proactive debuggers," identifying potential issues and suggesting fixes in real-time.
#     *   Facilitate sophisticated code reviews and security analysis, acting as an intelligent co-pilot.
#
# ### Section 3: Practical Applications and Future Potential for Developers
#
# *   **AI-Powered Development Assistants:** Imagine agents that can:
#     *   Generate boilerplate code based on specifications.
#     *   Suggest optimal algorithms or data structures.
#     *   Translate code between languages or refactor existing code.
# *   **Advanced Testing and Simulation:**
#     *   Develop agents that can intelligently explore software states and uncover edge cases that human testers might miss.
#     *   Create realistic simulation environments where agents interact with the software under test.
# *   **Self-Healing and Adaptive Software:**
#     *   Design systems where agents can detect and repair errors dynamically, increasing system resilience.
#     *   Enable software to adapt to changing environments or user needs autonomously.
#
# ### Section 4: Getting Started with Multi-Agent Systems
#
# *   **Learning the Ropes:** Briefly mention key concepts and technologies (e.g., agent communication languages, coordination mechanisms, agent platforms).
# *   **Choosing the Right Tools:** Introduce popular MAS frameworks and libraries (e.g., JADE, NetLogo, LangChain - depending on the focus).
# *   **Embracing the Mindset Shift:** Encourage developers to think about software not as a single entity, but as a collaborative ecosystem.
#
# **Concluding Thought:** Multi-Agent Systems are not just a futuristic concept; they are becoming a tangible reality that can empower software developers to build more sophisticated, efficient, and resilient applications. By embracing this paradigm, you can unlock new levels of productivity and innovation, transforming the way you code and the software you create.
# WriterAgent > ## Supercharge Your Code: How Multi-Agent Systems Will Revolutionize Software Development
#
# Are your software projects drowning in complexity? Imagine a world where intelligent "assistants" work collaboratively to streamline your development. This isn't science fiction; it's the promise of Multi-Agent Systems (MAS). MAS involves multiple independent software entities (agents) interacting to achieve shared goals, offering a powerful alternative to traditional monolithic applications.
#
# The benefits for developers are profound. MAS excels at **enhanced problem-solving and complexity management**, breaking down intricate challenges into smaller, manageable tasks distributed among specialized agents. This leads to more robust solutions forged from diverse perspectives.
#
# Furthermore, MAS promises **improved efficiency and automation**. Repetitive coding, testing, and debugging can be automated, freeing you to focus on creativity. Think CI/CD pipelines powered by agents that continuously monitor and act on code changes.
#
# Crucially, MAS offers **intelligent code assistance and quality assurance**. Agents can act as super-linters, proactive debuggers, and sophisticated code reviewers, identifying potential issues and suggesting fixes in real-time. Imagine an intelligent co-pilot assisting with code quality and security analysis.
#
# From generating boilerplate code to intelligent testing and even self-healing software, MAS is set to transform our development workflows. Embracing this paradigm means thinking of software as a collaborative ecosystem, unlocking new levels of productivity and innovation. Dive in and supercharge your code!
# EditorAgent > ## Supercharge Your Code: How Multi-Agent Systems Will Revolutionize Software Development
#
# Are your software projects struggling under the weight of complexity? Imagine a development process where intelligent "assistants" collaborate to streamline every stage, catch errors proactively, and elevate code quality. This isn't a futuristic dream; it's the transformative power of Multi-Agent Systems (MAS). MAS represents a paradigm shift, moving beyond traditional monolithic applications by employing multiple independent software entities, or "agents," that interact to achieve shared objectives.
#
# For software developers, the implications are profound. MAS shines in **enhanced problem-solving and complexity management**. By breaking down intricate challenges into smaller, manageable tasks distributed among specialized agents, MAS allows for the creation of more robust solutions, benefiting from the collective intelligence and diverse perspectives of its components.
#
# Beyond tackling complex logic, MAS offers significant gains in **improved efficiency and automation**. Repetitive tasks like coding, testing, and debugging can be largely automated, freeing developers to concentrate on creative problem-solving and higher-level design. Consider the potential for agent-powered CI/CD pipelines that continuously monitor code, identify issues, and initiate corrective actions automatically.
#
# Perhaps most exciting is the prospect of **intelligent code assistance and quality assurance**. Agents can function as sophisticated linters, proactive debuggers, and advanced code reviewers, identifying potential issues and suggesting real-time fixes. Picture an intelligent co-pilot that seamlessly integrates with your workflow, providing continuous analysis of code quality and security.
#
# From generating boilerplate code to orchestrating intelligent testing strategies and even enabling self-healing software, MAS is poised to fundamentally transform our development workflows. Embracing this paradigm means shifting our perspective: viewing software not as a singular entity, but as a dynamic, collaborative ecosystem. This shift unlocks unprecedented levels of productivity and innovation. Dive in and discover how you can supercharge your code with Multi-Agent Systems.

# %%
# Tech Researcher: Focuses on AI and ML trends.
tech_researcher = Agent(
    name="TechResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research the latest AI/ML trends. Include 3 key developments,
the main companies involved, and the potential impact. Keep the report very concise (100 words).""",
    tools=[google_search],
    output_key="tech_research",  # The result of this agent will be stored in the session state with this key.
)

print("✅ tech_researcher created.")
# Out:
# ✅ tech_researcher created.

# %%
# Health Researcher: Focuses on medical breakthroughs.
health_researcher = Agent(
    name="HealthResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research recent medical breakthroughs. Include 3 significant advances,
their practical applications, and estimated timelines. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="health_research",  # The result will be stored with this key.
)

print("✅ health_researcher created.")
# Out:
# ✅ health_researcher created.

# %%
# Finance Researcher: Focuses on fintech trends.
finance_researcher = Agent(
    name="FinanceResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research current fintech trends. Include 3 key trends,
their market implications, and the future outlook. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="finance_research",  # The result will be stored with this key.
)

print("✅ finance_researcher created.")
# Out:
# ✅ finance_researcher created.

# %%
# The AggregatorAgent runs *after* the parallel step to synthesize the results.
aggregator_agent = Agent(
    name="AggregatorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # It uses placeholders to inject the outputs from the parallel agents, which are now in the session state.
    instruction="""Combine these three research findings into a single executive summary:

    **Technology Trends:**
    {tech_research}

    **Health Breakthroughs:**
    {health_research}

    **Finance Innovations:**
    {finance_research}

    Your summary should highlight common themes, surprising connections, and the most important key takeaways from all three reports. The final summary should be around 200 words.""",
    output_key="executive_summary",  # This will be the final output of the entire system.
)

print("✅ aggregator_agent created.")
# Out:
# ✅ aggregator_agent created.

# %%
# The ParallelAgent runs all its sub-agents simultaneously.
parallel_research_team = ParallelAgent(
    name="ParallelResearchTeam",
    sub_agents=[tech_researcher, health_researcher, finance_researcher],
)

# This SequentialAgent defines the high-level workflow: run the parallel team first, then run the aggregator.
root_agent = SequentialAgent(
    name="ResearchSystem",
    sub_agents=[parallel_research_team, aggregator_agent],
)

print("✅ Parallel and Sequential Agents created.")
# Out:
# ✅ Parallel and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Run the daily executive briefing on Tech, Health, and Finance"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Run the daily executive briefing on Tech, Health, and Finance
# FinanceResearcher > Here's your executive briefing for November 15, 2025:
#
# **Technology:** Apple is reportedly intensifying its succession planning for CEO Tim Cook, with hardware engineering SVP John Ternus seen as a likely successor. This signals a significant leadership transition on the horizon for the tech giant.
#
# **Health:** Ethiopia has confirmed its first case of Marburg virus disease in Jinka, with Africa CDC commending the country's swift response measures. Globally, November 15th marks World Prematurity Day, emphasizing the critical need for specialized care for preterm infants.
#
# **Finance:** The 2025 Corporate Financial Reporting Insights (CFRI) Conference highlights key themes for financial leaders, including navigating geopolitical uncertainty, regulatory developments, and technological transformation. Discussions also focus on the evolving landscape of executive compensation and shareholder influence, with a growing trend in "say-on-pay" votes.
# TechResearcher > **Key AI/ML Trends Report: November 15, 2025**
#
# **1. Generative AI's Maturation:** Generative AI continues its rapid evolution, expanding beyond text to create complex graphics, video, and music. Companies like Google (Gemini, Imagen) and OpenAI (GPT models) are leading this charge, with applications enhancing artistic expression and practical content creation.
#
# **2. AI in Healthcare and Finance:** AI is significantly impacting healthcare through advanced diagnostics and personalized treatment, while in finance, it's revolutionizing fraud detection, risk analysis, and algorithmic trading. The healthcare AI market is projected for substantial growth, reaching nearly $188 billion by 2030. Major players include Amazon, IBM, and DataRobot, among others.
#
# **3. Explainable AI (XAI) and Ethical AI:** As AI systems become more integrated into critical sectors, transparency in decision-making is paramount. Explainable AI (XAI) is gaining importance to foster trust and meet regulatory demands, particularly in sensitive fields like healthcare and finance.
#
# **Potential Impact:** These trends promise increased efficiency through automation, enhanced decision-making via advanced analytics, and personalized user experiences across industries. However, they also bring challenges related to data privacy, ethical considerations, and the future of work.
# HealthResearcher > **Health Breakthroughs:**
#
# *   **Gene Therapy for Inherited Diseases:** Advances in gene therapy are enabling treatments for conditions like inherited hearing loss and sickle cell anemia. Practical applications include restoring function in patients with genetic disorders. Timeline: Currently in clinical use, with wider adoption expected within 5 years.
# *   **CAR T-Cell Therapy for Brain Cancer:** This method, which reengineers a patient's immune cells, is showing promise in treating brain cancers. It's already effective for blood cancers. Timeline: Clinical trials are ongoing, with potential for broader use in 5-10 years.
# *   **AI-Powered Diagnostics:** AI is enhancing the accuracy of medical scans, such as mammograms, and improving disease detection and treatment prediction using genomic data. Timeline: AI integration is ongoing, with significant impact expected in 3-5 years.
#
# **Technology Breakthroughs:**
#
# *   **Agentic AI Systems:** These AI systems can autonomously plan and execute complex workflows, acting as virtual coworkers. Practical applications include significant reductions in manual work across industries. Timeline: Expected to influence 15% of enterprise decisions by 2028.
# *   **Quantum Computing:** While still in early stages, quantum computing is demonstrating breakthroughs in complex simulations for drug discovery and logistics. Timeline: Practical applications are emerging, with significant market growth projected by 2030.
# *   **Biomanufacturing and Synthetic Biology:** Advances in precision fermentation and AI-driven biofoundries are leading to more sustainable production methods for various materials. Timeline: Innovations are rapidly developing, with widespread industry adoption anticipated within 5-7 years.
#
# **Finance Breakthroughs:**
#
# *   **AI and Machine Learning in Finance:** AI/ML are revolutionizing risk decisioning, algorithmic trading, and personalized financial services. Practical applications include enhanced fraud detection and automated underwriting. Timeline: Already integral, with further advancements expected in 2-3 years.
# *   **Blockchain for Financial Services:** Blockchain is enabling secure, transparent platforms for digital bonds, DeFi, and improved fraud prevention. Timeline: Continued integration is expected, with wider adoption of blockchain-based financial instruments in 3-5 years.
# *   **Digital Assets and CBDCs:** The rise of digital assets and central bank digital currencies (CBDCs) is transforming payment, lending, and banking infrastructure. Timeline: Rapid development is occurring, with significant market shifts anticipated in 4-6 years.
# AggregatorAgent > ## Executive Summary: November 15, 2025
#
# Artificial intelligence (AI) continues its profound integration across technology, health, and finance, promising significant advancements and operational efficiencies. Generative AI is rapidly evolving, expanding creative and content generation capabilities. In healthcare, AI is revolutionizing diagnostics and personalized treatments, with AI-powered diagnostics expected to have a major impact within 3-5 years, while gene and CAR T-cell therapies offer new hope for inherited diseases and cancers.
#
# The finance sector is leveraging AI and blockchain for enhanced fraud detection, risk management, and new digital asset platforms, with significant market shifts anticipated. "Agentic AI systems" are emerging as virtual coworkers, poised to influence enterprise decisions by 2028.
#
# A key common theme is the growing importance of **Explainable AI (XAI)** and ethical considerations, particularly as AI becomes more embedded in critical sectors like healthcare and finance, necessitating transparency and trust. While these technological leaps offer increased efficiency and innovation, leaders must also navigate challenges related to data privacy, ethical implications, and the future of work, as highlighted by discussions at the CFRI Conference. Separately, a leadership transition is reportedly underway at Apple, and a Marburg virus case in Ethiopia underscores ongoing global health vigilance.

# %%
# This agent runs ONCE at the beginning to create the first draft.
initial_writer_agent = Agent(
    name="InitialWriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Based on the user's prompt, write the first draft of a short story (around 100-150 words).
    Output only the story text, with no introduction or explanation.""",
    output_key="current_story",  # Stores the first draft in the state.
)

print("✅ initial_writer_agent created.")
# Out:
# ✅ initial_writer_agent created.

# %%
# This agent's only job is to provide feedback or the approval signal. It has no tools.
critic_agent = Agent(
    name="CriticAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a constructive story critic. Review the story provided below.
    Story: {current_story}

    Evaluate the story's plot, characters, and pacing.
    - If the story is well-written and complete, you MUST respond with the exact phrase: "APPROVED"
    - Otherwise, provide 2-3 specific, actionable suggestions for improvement.""",
    output_key="critique",  # Stores the feedback in the state.
)

print("✅ critic_agent created.")
# Out:
# ✅ critic_agent created.

# %%
# This is the function that the RefinerAgent will call to exit the loop.
def exit_loop():
    """Call this function ONLY when the critique is 'APPROVED', indicating the story is finished and no more changes are needed."""
    return {"status": "approved", "message": "Story approved. Exiting refinement loop."}


print("✅ exit_loop function created.")
# Out:
# ✅ exit_loop function created.

# %%
# This agent refines the story based on critique OR calls the exit_loop function.
refiner_agent = Agent(
    name="RefinerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a story refiner. You have a story draft and critique.

    Story Draft: {current_story}
    Critique: {critique}

    Your task is to analyze the critique.
    - IF the critique is EXACTLY "APPROVED", you MUST call the `exit_loop` function and nothing else.
    - OTHERWISE, rewrite the story draft to fully incorporate the feedback from the critique.""",
    output_key="current_story",  # It overwrites the story with the new, refined version.
    tools=[
        FunctionTool(exit_loop)
    ],  # The tool is now correctly initialized with the function reference.
)

print("✅ refiner_agent created.")
# Out:
# ✅ refiner_agent created.

# %%
# The LoopAgent contains the agents that will run repeatedly: Critic -> Refiner.
story_refinement_loop = LoopAgent(
    name="StoryRefinementLoop",
    sub_agents=[critic_agent, refiner_agent],
    max_iterations=2,  # Prevents infinite loops
)

# The root agent is a SequentialAgent that defines the overall workflow: Initial Write -> Refinement Loop.
root_agent = SequentialAgent(
    name="StoryPipeline",
    sub_agents=[initial_writer_agent, story_refinement_loop],
)

print("✅ Loop and Sequential Agents created.")
# Out:
# ✅ Loop and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a short story about a lighthouse keeper who discovers a mysterious, glowing map"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a short story about a lighthouse keeper who discovers a mysterious, glowing map
# InitialWriterAgent > Elias polished the lantern, its beam a familiar comfort against the encroaching fog. For twenty years, the lonely tower had been his world. Tonight, however, something unusual lay snagged on the rocks below. Hauling it up, he found a rolled-up parchment, impossibly dry. Unfurling it, he gasped. The map glowed with an ethereal, cerulean light, depicting not known lands, but swirling currents and constellations he’d never seen. Strange symbols pulsed along the waterways. Was it a treasure map? A portal? Elias felt a thrill, a forgotten spark of adventure, ignite within him. The sea, usually a predictable expanse, suddenly held a thousand new secrets.
# CriticAgent > This is a promising start to a story with a good hook! Here are a few suggestions for improvement:
#
# 1.  **Show, Don't Tell Elias's Loneliness:** While the story states Elias has been in the tower for twenty years and it's his "world," we don't *feel* his loneliness. Consider adding a brief moment illustrating his routine or a thought that emphasizes his isolation *before* the map appears. This will make the "forgotten spark of adventure" more impactful. For example, a sentence about him talking to the gulls or the way the silence usually presses in.
#
# 2.  **Enhance the Mystery of the Map:** The description of the map is good, but could be even more evocative. Instead of just "swirling currents and constellations he’d never seen," perhaps describe *how* they look or feel alien. Are the constellations arranged in impossible shapes? Do the currents seem to flow with an unseen force? The "strange symbols" are a great detail; consider giving a hint of their nature – are they geometric, organic, runic?
#
# 3.  **Strengthen Elias's Reaction:** Elias's gasp and the ignition of his spark are good, but his internal reaction could be deepened. What are his immediate thoughts beyond "treasure map? portal?" Does he feel fear mixed with excitement? Does he question his sanity? A slightly more detailed internal monologue would make his character more relatable and his discovery more profound.
# RefinerAgent > Elias polished the lantern, its beam a familiar comfort against the encroaching fog. For twenty years, the lonely tower had been his world, a silent sentinel against the sea's fury. His only companions were the gulls that cried outside his window and the endless drone of the waves, a symphony of isolation he’d long since grown accustomed to. Tonight, however, something unusual lay snagged on the rocks below. Hauling it up, he found a rolled-up parchment, impossibly dry. Unfurling it, he gasped. The map glowed with an ethereal, cerulean light, depicting not known lands, but swirling currents that seemed to writhe with a life of their own, and constellations arranged in impossible, alien geometries. Strange, runic symbols pulsed along the waterways, hinting at a language long dead. Was it a treasure map? A portal to another realm? Elias’s heart hammered against his ribs, a chaotic drumbeat of fear and exhilaration. He gripped the parchment, his knuckles white, a forgotten spark of adventure igniting within him, brighter than the lantern’s steady beam. The sea, usually a predictable expanse of gray, suddenly held a thousand new, terrifying secrets.
# CriticAgent > APPROVED
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
