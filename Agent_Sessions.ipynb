# %% [markdown]
# <a href="https://colab.research.google.com/github/agterzis/ADK-AI-Agent/blob/main/Agent_Sessions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import userdata
import google.generativeai as genai

try:
    GOOGLE_API_KEY = userdata.get("GOOGLE_API_KEY")
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY # Set as environment variable
    genai.configure(api_key=GOOGLE_API_KEY) # Configure google.generativeai globally
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print(
        f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Colab secrets. Details: {e}"
    )
# Out:
# ✅ Gemini API key setup complete.

# %%
from typing import Any, Dict

from google.adk.agents import Agent, LlmAgent
from google.adk.apps.app import App, EventsCompactionConfig
from google.adk.models.google_llm import Gemini
from google.adk.sessions import DatabaseSessionService
from google.adk.sessions import InMemorySessionService
from google.adk.runners import Runner
from google.adk.tools.tool_context import ToolContext
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
# Define helper functions that will be reused throughout the notebook
async def run_session(
    runner_instance: Runner,
    user_queries: list[str] | str = None,
    session_name: str = "default",
):
    print(f"\n ### Session: {session_name}")

    # Get app name from the Runner
    app_name = runner_instance.app_name

    # Attempt to create a new session or retrieve an existing one
    try:
        session = await session_service.create_session(
            app_name=app_name, user_id=USER_ID, session_id=session_name
        )
    except:
        session = await session_service.get_session(
            app_name=app_name, user_id=USER_ID, session_id=session_name
        )

    # Process queries if provided
    if user_queries:
        # Convert single query to list for uniform processing
        if type(user_queries) == str:
            user_queries = [user_queries]

        # Process each query in the list sequentially
        for query in user_queries:
            print(f"\nUser > {query}")

            # Convert the query string to the ADK Content format
            query = types.Content(role="user", parts=[types.Part(text=query)])

            # Stream the agent's response asynchronously
            async for event in runner_instance.run_async(
                user_id=USER_ID, session_id=session.id, new_message=query
            ):
                # Check if the event contains valid content
                if event.content and event.content.parts:
                    # Filter out empty or "None" responses before printing
                    if (
                        event.content.parts[0].text != "None"
                        and event.content.parts[0].text
                    ):
                        print(f"{MODEL_NAME} > ", event.content.parts[0].text)
    else:
        print("No queries!")


print("✅ Helper functions defined.")
# Out:
# ✅ Helper functions defined.

# %%
retry_config = types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504],  # Retry on these HTTP errors
)

# %%
APP_NAME = "default"  # Application
USER_ID = "default"  # User
SESSION = "default"  # Session

MODEL_NAME = "gemini-2.5-flash-lite"


# Step 1: Create the LLM Agent
root_agent = Agent(
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    name="text_chat_bot",
    description="A text chatbot",  # Description of the agent's purpose
)

# Step 2: Set up Session Management
# InMemorySessionService stores conversations in RAM (temporary)
session_service = InMemorySessionService()

# Step 3: Create the Runner
runner = Runner(agent=root_agent, app_name=APP_NAME, session_service=session_service)

print("✅ Stateful agent initialized!")
print(f"   - Application: {APP_NAME}")
print(f"   - User: {USER_ID}")
print(f"   - Using: {session_service.__class__.__name__}")
# Out:
# ✅ Stateful agent initialized!
#    - Application: default
#    - User: default
#    - Using: InMemorySessionService

# %%
# Run a conversation with two queries in the same session
# Notice: Both queries are part of the SAME session, so context is maintained
await run_session(
    runner,
    [
        "Hi, I am Sam! What is the capital of United States?",
        "Hello! What is my name?",  # This time, the agent should remember!
    ],
    "stateful-agentic-session",
)
# Out:
#  ### Session: stateful-agentic-session
#
# User > Hi, I am Sam! What is the capital of United States?
# gemini-2.5-flash-lite >  Hi Sam! The capital of the United States is Washington, D.C.
#
# User > Hello! What is my name?
# gemini-2.5-flash-lite >  Your name is Sam.

# %%
# Run this cell after restarting the kernel. All this history will be gone...
await run_session(
    runner,
    ["What did I ask you about earlier?", "And remind me, what's my name?"],
    "stateful-agentic-session",
)  # Note, we are using same session name
# Out:
#  ### Session: stateful-agentic-session
#
# User > What did I ask you about earlier?
# gemini-2.5-flash-lite >  You asked me about the capital of the United States.
#
# User > And remind me, what's my name?
# gemini-2.5-flash-lite >  Your name is Sam.

# %%
# Step 1: Create the same agent (notice we use LlmAgent this time)
chatbot_agent = LlmAgent(
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    name="text_chat_bot",
    description="A text chatbot with persistent memory",
)

# Step 2: Switch to DatabaseSessionService
# SQLite database will be created automatically
db_url = "sqlite:///my_agent_data.db"  # Local SQLite file
session_service = DatabaseSessionService(db_url=db_url)

# Step 3: Create a new runner with persistent storage
runner = Runner(agent=chatbot_agent, app_name=APP_NAME, session_service=session_service)

print("✅ Upgraded to persistent sessions!")
print(f"   - Database: my_agent_data.db")
print(f"   - Sessions will survive restarts!")
# Out:
# ✅ Upgraded to persistent sessions!
#    - Database: my_agent_data.db
#    - Sessions will survive restarts!

# %%
await run_session(
    runner,
    ["Hi, I am Sam! What is the capital of the United States?", "Hello! What is my name?"],
    "test-db-session-01",
)
# Out:
#  ### Session: test-db-session-01
#
# User > Hi, I am Sam! What is the capital of the United States?
# gemini-2.5-flash-lite >  Hi Sam! The capital of the United States is Washington, D.C.
#
# User > Hello! What is my name?
# gemini-2.5-flash-lite >  Your name is Sam.

# %%
await run_session(
    runner,
    ["What is the capital of India?", "Hello! What is my name?"],
    "test-db-session-01",
)
# Out:
#  ### Session: test-db-session-01
#
# User > What is the capital of India?
# gemini-2.5-flash-lite >  The capital of India is New Delhi.
#
# User > Hello! What is my name?
# gemini-2.5-flash-lite >  Your name is Sam.

# %%
await run_session(
    runner, ["Hello! What is my name?"], "test-db-session-02"
)  # Note, we are using new session name
# Out:
#  ### Session: test-db-session-02
#
# User > Hello! What is my name?
# gemini-2.5-flash-lite >  I do not have access to your personal information, including your name. Therefore, I cannot tell you what your name is.

# %%
import sqlite3

def check_data_in_db():
    with sqlite3.connect("my_agent_data.db") as connection:
        cursor = connection.cursor()
        result = cursor.execute(
            "select app_name, session_id, author, content from events"
        )
        print([_[0] for _ in result.description])
        for each in result.fetchall():
            print(each)


check_data_in_db()
# Out:
# ['app_name', 'session_id', 'author', 'content']
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "Hi, I am Sam! What is the capital of the United States?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "Hi Sam! The capital of the United States is Washington, D.C."}], "role": "model"}')
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "Hello! What is my name?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "Your name is Sam."}], "role": "model"}')
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "What is the capital of India?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "The capital of India is New Delhi."}], "role": "model"}')
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "Hello! What is my name?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "Your name is Sam."}], "role": "model"}')
# ('default', 'test-db-session-02', 'user', '{"parts": [{"text": "What is the capital of India?"}], "role": "user"}')
# ('default', 'test-db-session-02', 'text_chat_bot', '{"parts": [{"text": "The capital of India is New Delhi."}], "role": "model"}')
# ('default', 'test-db-session-02', 'user', '{"parts": [{"text": "Hello! What is my name?"}], "role": "user"}')
# ('default', 'test-db-session-02', 'text_chat_bot', '{"parts": [{"text": "I do not have access to your personal information, including your name. Therefore, I cannot tell you what your name is."}], "role": "model"}')
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "What is the capital of India?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "The capital of India is New Delhi."}], "role": "model"}')
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "Hello! What is my name?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "Your name is Sam."}], "role": "model"}')
# ('default', 'test-db-session-02', 'user', '{"parts": [{"text": "Hello! What is my name?"}], "role": "user"}')
# ('default', 'test-db-session-02', 'text_chat_bot', '{"parts": [{"text": "I do not have access to your personal information, including your name. Therefore, I cannot tell you what your name is."}], "role": "model"}')
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "Hello! What is my name?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "Your name is Sam."}], "role": "model"}')
# ('default', 'test-db-session-02', 'user', '{"parts": [{"text": "Hello! What is my name?"}], "role": "user"}')
# ('default', 'test-db-session-02', 'text_chat_bot', '{"parts": [{"text": "I do not have access to your personal information, including your name. Therefore, I cannot tell you what your name is."}], "role": "model"}')

# %% [markdown]
# Create an App for the agent

# %%
# Re-define our app with Events Compaction enabled
research_app_compacting = App(
    name="research_app_compacting",
    root_agent=chatbot_agent,
    # This is the new part!
    events_compaction_config=EventsCompactionConfig(
        compaction_interval=3,  # Trigger compaction every 3 invocations
        overlap_size=1,  # Keep 1 previous turn for context
    ),
)

db_url = "sqlite:///my_agent_data.db"  # Local SQLite file
session_service = DatabaseSessionService(db_url=db_url)

# Create a new runner for our upgraded app
research_runner_compacting = Runner(
    app=research_app_compacting, session_service=session_service
)


print("✅ Research App upgraded with Events Compaction!")
# Out:
# ✅ Research App upgraded with Events Compaction!
# /tmp/ipython-input-3773147741.py:6: UserWarning: [EXPERIMENTAL] EventsCompactionConfig: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   events_compaction_config=EventsCompactionConfig(

# %%
# Turn 1
await run_session(
    research_runner_compacting,
    "What is the latest news about AI in healthcare?",
    "compaction_demo",
)

# Turn 2
await run_session(
    research_runner_compacting,
    "Are there any new developments in drug discovery?",
    "compaction_demo",
)

# Turn 3 - Compaction should trigger after this turn!
await run_session(
    research_runner_compacting,
    "Tell me more about the second development you found.",
    "compaction_demo",
)

# Turn 4
await run_session(
    research_runner_compacting,
    "Who are the main companies involved in that?",
    "compaction_demo",
)
# Out:
#  ### Session: compaction_demo
#
# User > What is the latest news about AI in healthcare?
# gemini-2.5-flash-lite >  Here's a summary of some of the latest news and trends in AI in healthcare:
#
# **Key Areas of Advancement and Focus:**
#
# *   **Drug Discovery and Development:** AI continues to revolutionize this field. Companies are using AI to:
#     *   **Identify novel drug candidates:** Analyzing vast datasets of biological and chemical information to pinpoint potential molecules.
#     *   **Predict drug efficacy and toxicity:** Reducing the time and cost of preclinical trials.
#     *   **Design personalized therapies:** Tailoring treatments based on individual patient genetics and disease profiles.
#     *   **Recent news highlights:** Several AI-powered drug discovery companies have announced significant funding rounds and partnerships with major pharmaceutical firms. There's also growing interest in using AI for the development of treatments for rare diseases.
#
# *   **Medical Imaging and Diagnostics:** AI algorithms are becoming increasingly sophisticated at analyzing medical images (X-rays, CT scans, MRIs, pathology slides) to:
#     *   **Detect diseases earlier and more accurately:** Identifying subtle patterns that might be missed by human eyes. This is particularly true for cancers, diabetic retinopathy, and cardiovascular conditions.
#     *   **Automate routine tasks:** Freeing up radiologists and pathologists to focus on more complex cases.
#     *   **Enhance image quality and reduce scan times.**
#     *   **Recent news highlights:** FDA approvals for new AI-powered diagnostic tools are a frequent occurrence. There's also a push to integrate these tools seamlessly into existing clinical workflows.
#
# *   **Personalized Medicine and Treatment Planning:** AI is enabling a more tailored approach to patient care by:
#     *   **Analyzing patient data (genomics, electronic health records, wearables) to predict disease risk and treatment response.**
#     *   **Developing personalized treatment plans that optimize outcomes and minimize side effects.**
#     *   **Identifying patients who would benefit most from specific interventions.**
#     *   **Recent news highlights:** Advances in AI for analyzing complex genomic data are leading to more targeted cancer therapies.
#
# *   **Robotics and AI-Assisted Surgery:** AI is enhancing surgical procedures by:
#     *   **Improving robotic surgical systems with enhanced precision and navigation.**
#     *   **Providing real-time guidance to surgeons based on pre-operative imaging and intra-operative data.**
#     *   **Automating certain repetitive surgical tasks.**
#     *   **Recent news highlights:** Developments in AI-powered surgical planning software and enhanced sensor technology for robotic arms.
#
# *   **Virtual Assistants and Patient Engagement:** AI-powered chatbots and virtual assistants are being used to:
#     *   **Provide patients with information and support.**
#     *   **Schedule appointments and manage prescriptions.**
#     *   **Monitor patient symptoms remotely.**
#     *   **Improve patient adherence to treatment plans.**
#     *   **Recent news highlights:** Increased adoption of AI-powered tools for mental health support and chronic disease management.
#
# *   **Administrative Efficiency and Workflow Optimization:** AI is helping healthcare organizations by:
#     *   **Automating tasks like medical coding, billing, and appointment scheduling.**
#     *   **Optimizing hospital resource allocation and patient flow.**
#     *   **Reducing administrative burden on healthcare professionals.**
#     *   **Recent news highlights:** Focus on leveraging AI to address physician burnout by reducing administrative overhead.
#
# **Emerging Trends and Challenges:**
#
# *   **Generative AI (like GPT-4):** While still in its early stages of adoption in healthcare, generative AI shows promise for:
#     *   **Summarizing medical literature.**
#     *   **Drafting clinical notes and patient communications.**
#     *   **Assisting in medical education and training.**
#     *   **However, significant ethical and regulatory hurdles remain, particularly concerning accuracy, bias, and patient privacy.**
# *   **Explainable AI (XAI):** There's a growing demand for AI systems that can explain their decision-making processes, crucial for building trust with clinicians and patients.
# *   **Data Privacy and Security:** Ensuring the secure and ethical handling of sensitive patient data remains a paramount concern.
# *   **Regulatory Approval and Integration:** Navigating the complex regulatory landscape for AI in healthcare and integrating these technologies seamlessly into existing clinical workflows are ongoing challenges.
# *   **Addressing Bias in AI:** It's critical to ensure AI algorithms are trained on diverse datasets to avoid perpetuating or amplifying existing health disparities.
#
# **Where to Find More Information:**
#
# For the most up-to-date news, I recommend checking:
#
# *   **Reputable healthcare technology news outlets:** FierceHealthcare, MobiHealthNews, Healthcare IT News, STAT News.
# *   **Medical journals and research publications:** Nature Medicine, The Lancet Digital Health, JAMA.
# *   **Major AI conferences and their proceedings:** NeurIPS, ICML, AAAI (often have healthcare tracks).
# *   **Press releases from leading AI companies in healthcare and major pharmaceutical companies.**
#
# The field of AI in healthcare is rapidly evolving, with new breakthroughs and applications emerging constantly.
#
#  ### Session: compaction_demo
#
# User > Are there any new developments in drug discovery?
# gemini-2.5-flash-lite >  Yes, absolutely! Drug discovery remains one of the most dynamic and promising areas for AI in healthcare. Here are some of the latest developments and ongoing trends:
#
# **1. Accelerating Target Identification and Validation:**
#
# *   **AI for Genomics and Proteomics:** Advanced AI models are now capable of sifting through massive datasets of genomic, proteomic, and transcriptomic data to identify novel disease targets that were previously unknown or considered "undruggable." This involves understanding complex biological pathways and pinpointing key proteins or genes involved in disease.
# *   **Network Biology Analysis:** AI is being used to map out intricate biological networks, understanding how different molecules interact. This helps identify crucial nodes within these networks that, when targeted, could have a significant therapeutic effect.
# *   **Predicting Target Druggability:** AI algorithms can now predict how likely a specific biological target is to be successfully modulated by a small molecule or biologic drug, saving significant time and resources on targets that are unlikely to yield a viable drug.
#
# **2. Revolutionizing Molecule Design and Optimization:**
#
# *   **Generative AI for Novel Molecule Design:** This is a huge area of advancement. Generative AI models (like those based on transformer architectures or variational autoencoders) are being trained on vast libraries of known drugs and chemical compounds. They can then:
#     *   **Generate entirely new molecular structures** that have desired properties (e.g., binding affinity to a target, low toxicity, good pharmacokinetic profiles).
#     *   **"De novo" drug design:** Creating molecules from scratch, rather than just optimizing existing ones.
# *   **AI-Driven Lead Optimization:** Once a promising "lead" compound is identified, AI can rapidly explore modifications to improve its efficacy, safety, and delivery. This includes predicting ADMET (Absorption, Distribution, Metabolism, Excretion, Toxicity) properties.
# *   **Quantum Computing and AI Synergy:** While still nascent, there's growing interest in combining quantum computing's power for simulating molecular interactions with AI's ability to analyze and predict outcomes. This could unlock unprecedented capabilities in molecular design.
#
# **3. Enhancing Preclinical and Clinical Trial Efficiency:**
#
# *   **Predicting Drug Efficacy and Toxicity:** AI models are becoming better at predicting how a drug candidate will perform in preclinical animal studies and, importantly, in human clinical trials. This can help prioritize candidates with a higher likelihood of success and de-prioritize those with high risks of failure.
# *   **Patient Stratification for Clinical Trials:** AI can analyze patient data to identify subgroups that are more likely to respond to a particular drug. This allows for more targeted and efficient clinical trials, potentially leading to faster approvals and better outcomes for specific patient populations.
# *   **Repurposing Existing Drugs:** AI can analyze vast databases of existing drugs and their known effects, as well as disease pathways, to identify potential new uses for approved medications, a much faster and cheaper route than developing entirely new drugs.
# *   **Designing More Efficient Trial Protocols:** AI can help optimize clinical trial design by predicting optimal dosage, trial duration, and endpoint selection.
#
# **4. Key Players and Recent News:**
#
# *   **Biotechs and Startups:** Many innovative companies are at the forefront of AI-driven drug discovery. Companies like **Recursion Pharmaceuticals, Exscientia, BenevolentAI, Atomwise, Insilico Medicine, and Schrödinger** are frequently in the news for significant funding rounds, partnerships with major pharmaceutical companies, and announcing progress on their drug pipelines.
# *   **Big Pharma Partnerships:** Major pharmaceutical giants (Pfizer, Novartis, AstraZeneca, Merck, etc.) are actively investing in and partnering with AI drug discovery companies, recognizing the transformative potential.
# *   **Specific Therapeutic Areas:** AI is seeing particular traction in areas like **oncology, neurodegenerative diseases (e.g., Alzheimer's), and infectious diseases**. The complexity of these diseases often requires sophisticated analytical tools.
#
# **Challenges and the Future:**
#
# Despite the rapid progress, challenges remain:
#
# *   **Data Quality and Accessibility:** High-quality, diverse, and well-annotated datasets are crucial for training robust AI models.
# *   **Interpretability of AI Models:** Understanding *why* an AI model makes a certain prediction is vital for scientific validation and regulatory approval.
# *   **Regulatory Pathways:** Establishing clear regulatory pathways for AI-discovered drugs is an ongoing process.
# *   **Integration into Existing Workflows:** Seamlessly integrating AI tools into traditional R&D processes requires cultural shifts and new infrastructure.
#
# In summary, AI is no longer a futuristic concept in drug discovery; it's a powerful, operational tool that is fundamentally changing how new medicines are identified, designed, and tested. The pace of innovation is rapid, and we can expect to see many more AI-discovered drugs entering clinical trials and eventually reaching patients in the coming years.
#
#  ### Session: compaction_demo
#
# User > Tell me more about the second development you found.
# gemini-2.5-flash-lite >  You're asking about the second development I mentioned in the context of AI in drug discovery, which is:
#
# **2. Revolutionizing Molecule Design and Optimization**
#
# This area is particularly exciting because it's where AI directly intervenes in the creative and intricate process of designing new drug molecules. Here's a deeper dive:
#
# **The Core Problem AI is Addressing:**
#
# Traditionally, drug discovery involves a lot of trial and error. Chemists synthesize thousands of compounds, test them against a target, and then modify the most promising ones. This is:
#
# *   **Time-consuming:** Synthesizing and testing each molecule takes weeks or months.
# *   **Expensive:** The cost of materials, equipment, and labor is immense.
# *   **Limited in scope:** Human chemists can only explore a fraction of the vast chemical space (all possible molecular structures).
#
# **How AI is Changing This:**
#
# AI, especially **generative AI**, is changing this paradigm by acting like an intelligent "molecular architect."
#
# **a) Generative AI for Novel Molecule Design (De Novo Design):**
#
# *   **What it is:** These AI models are trained on enormous datasets of existing chemical compounds (often millions or even billions). They learn the "rules" of chemistry – how atoms bond, what makes a molecule stable, what functional groups are important for certain properties, and what chemical structures are associated with known biological activity.
# *   **How it works (simplified):**
#     *   **Learning the Language of Molecules:** Think of it like teaching an AI to write sentences. It learns the "grammar" and "vocabulary" of molecules.
#     *   **Generating New "Sentences":** Once trained, the AI can generate entirely new molecular structures that have never been synthesized before.
#     *   **Targeted Generation:** Crucially, these models aren't just generating random molecules. They are guided by specific objectives. For example, you can tell the AI: "Design a molecule that binds strongly to protein X, has a molecular weight under 500 Daltons, and is unlikely to cause liver toxicity."
# *   **Types of Generative Models Used:**
#     *   **Variational Autoencoders (VAEs):** Learn a compressed representation of molecules and can then decode it to generate new ones.
#     *   **Generative Adversarial Networks (GANs):** Two neural networks (a generator and a discriminator) compete, with the generator trying to create realistic molecules and the discriminator trying to tell them apart from real ones.
#     *   **Transformer Networks:** Similar to those used in language processing, these can be adapted to understand and generate sequential representations of molecules.
# *   **Benefits:**
#     *   **Vast Exploration of Chemical Space:** AI can explore chemical possibilities that are beyond human intuition or computational capacity with traditional methods.
#     *   **Faster Innovation:** Reduces the time it takes to identify novel starting points for drug development.
#     *   **Design for Specific Properties:** Allows for the design of molecules with a tailored set of desired characteristics from the outset.
#
# **b) AI-Driven Lead Optimization:**
#
# *   **What it is:** Once a promising "lead compound" is found (either through traditional methods or AI de novo design), AI can accelerate the process of refining it.
# *   **How it works:**
#     *   **Predicting Property Improvements:** AI models can predict how small chemical modifications to a lead compound will affect its properties, such as:
#         *   **Binding Affinity:** How well it sticks to its target.
#         *   **Potency:** The concentration needed for an effect.
#         *   **Selectivity:** How specifically it interacts with the target versus other molecules.
#         *   **ADMET Properties:** Absorption, Distribution, Metabolism, Excretion, and Toxicity – crucial for a drug to be safe and effective in the body.
#     *   **Suggesting Modifications:** AI can suggest specific chemical changes to make to a molecule to improve its profile.
#     *   **Virtual Screening of Derivatives:** AI can rapidly screen millions of potential modifications to a lead compound *in silico* (on a computer) before any synthesis is done in the lab.
# *   **Benefits:**
#     *   **Shorter Optimization Cycles:** Dramatically speeds up the process of turning a promising lead into a drug candidate.
#     *   **Reduced Experimental Burden:** Fewer compounds need to be synthesized and tested experimentally.
#     *   **Improved Drug Profiles:** Leads to drug candidates with better efficacy and safety.
#
# **c) Quantum Computing and AI Synergy:**
#
# *   **The Potential:** While still an emerging area, quantum computing offers the potential to simulate molecular interactions with unprecedented accuracy.
# *   **The Synergy:** AI can be used to guide quantum computations, interpret their results, and learn from them to refine its own predictive capabilities. This combination could lead to breakthroughs in understanding complex molecular dynamics and designing highly specific drugs.
#
# **In essence, AI in molecule design is moving drug discovery from an art of educated guesswork to a more predictable, data-driven science.** It's about using computational power to explore a universe of chemical possibilities, identify the most promising ones, and refine them efficiently. This is a fundamental shift that is making the drug discovery process faster, cheaper, and more likely to succeed.
#
#  ### Session: compaction_demo
#
# User > Who are the main companies involved in that?
# gemini-2.5-flash-lite >  You're asking about the companies leading the charge in **AI-driven molecule design and optimization**. This is a dynamic space with a mix of established pharmaceutical giants and specialized AI biotech startups.
#
# Here are some of the key players, often categorized by their approach or stage of development:
#
# **1. Specialized AI Drug Discovery Companies (Often Leading the "De Novo" Design):**
#
# These companies were founded with AI at their core, focusing specifically on using advanced algorithms to design novel molecules.
#
# *   **Exscientia:** A prominent leader that uses its AI platform for both target identification and de novo drug design. They have a significant pipeline of AI-designed drugs in clinical trials, often in partnership with larger pharma.
# *   **Recursion Pharmaceuticals:** While their platform also uses imaging and other biological data, they are heavily involved in identifying targets and designing compounds based on their AI-powered understanding of cellular biology.
# *   **BenevolentAI:** Known for its AI platform that integrates vast amounts of biomedical data to identify novel drug targets and design molecules. They have a growing pipeline and partnerships.
# *   **Atomwise:** One of the pioneers in using deep learning for drug discovery, particularly for protein-ligand interaction prediction and virtual screening. They focus on identifying potential drug candidates for specific targets.
# *   **Insilico Medicine:** This company is well-known for its end-to-end AI platform, including generative AI for de novo drug design. They've had notable successes in bringing AI-discovered drugs to clinical trials rapidly.
# *   **Schrödinger:** While not solely an AI company, Schrödinger is a leader in *computational chemistry and physics-based modeling* for drug discovery. They are increasingly integrating AI and machine learning into their highly sophisticated simulation tools, which are used by many pharma companies. Their platform is used for both target understanding and molecule design.
# *   **Helsinn BGM:** A smaller company, but they've been highlighted for their use of AI to design novel molecules, particularly in specific therapeutic areas.
#
# **2. Large Pharmaceutical Companies (Adopting and Investing in AI):**
#
# Major pharmaceutical companies are no longer just observing; they are actively investing in, acquiring, and building their own internal AI capabilities for molecule design.
#
# *   **Pfizer:** Has been actively using AI and machine learning for various stages of drug discovery, including target identification and lead optimization. They also form strategic partnerships.
# *   **Novartis:** A significant player in adopting AI for drug discovery, often integrating AI into their existing R&D processes and collaborating with AI startups.
# *   **AstraZeneca:** Has invested heavily in AI and data science, including for molecule design and optimization.
# *   **Merck:** Similar to others, Merck is leveraging AI for various discovery and development activities.
# *   **Johnson & Johnson (Janssen):** Actively exploring AI for drug discovery, often through internal initiatives and collaborations.
# *   **Roche / Genentech:** Strong focus on data-driven R&D, including the application of AI in designing and discovering new therapies.
#
# **3. Technology and Cloud Providers:**
#
# While not directly designing molecules, these companies provide the crucial infrastructure and AI/ML platforms that enable drug discovery companies to operate.
#
# *   **NVIDIA:** Their GPUs are essential for training complex AI models, and they are developing specialized software (like Clara) for life sciences that includes drug discovery tools.
# *   **Google Cloud, Amazon Web Services (AWS), Microsoft Azure:** Provide the scalable cloud computing power, storage, and AI/ML services needed for large-scale drug discovery computations.
#
# **4. Quantum Computing Companies (Emerging Players):**
#
# These are often early-stage companies exploring the intersection of quantum computing and AI for molecular simulation and design.
#
# *   **IBM Quantum:** Developing quantum computing hardware and software that can be applied to chemistry problems.
# *   **IonQ, Rigetti Computing:** Other players in the quantum hardware space whose technology could eventually be leveraged for drug discovery.
#
# **Key Trends in Company Activity:**
#
# *   **Partnerships and Collaborations:** This is extremely common. Big Pharma partners with AI startups to access cutting-edge technology, while startups gain access to vast datasets, expertise, and potential funding.
# *   **Acquisitions:** Larger companies may acquire AI drug discovery firms outright to bring their technology in-house.
# *   **Internal AI Development:** Many pharma companies are building substantial internal teams and capabilities in AI and data science.
# *   **Focus on Specific Modalities:** Some companies specialize in small molecules, others in biologics, and some are exploring new modalities like RNA therapeutics.
#
# It's a rapidly evolving landscape, and new companies and partnerships are forming all the time. The common thread is the recognition that AI is no longer a supplement but a fundamental tool for modern drug discovery, particularly in the design of novel molecular entities.

# %%
# Get the final session state
final_session = await session_service.get_session(
    app_name=research_runner_compacting.app_name,
    user_id=USER_ID,
    session_id="compaction_demo",
)

print("--- Searching for Compaction Summary Event ---")
found_summary = False
for event in final_session.events:
    # Compaction events have a 'compaction' attribute
    if event.actions and event.actions.compaction:
        print("\n✅ SUCCESS! Found the Compaction Event:")
        print(f"  Author: {event.author}")
        print(f"\n Compacted information: {event}")
        found_summary = True
        break

if not found_summary:
    print(
        "\n❌ No compaction event found. Try increasing the number of turns in the demo."
    )
# Out:
# --- Searching for Compaction Summary Event ---
#
# ✅ SUCCESS! Found the Compaction Event:
#   Author: user
#
#  Compacted information: model_version=None content=None grounding_metadata=None partial=None turn_complete=None finish_reason=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=None live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None invocation_id='56d70f60-1ab1-4572-9a68-1d19a062e9b6' author='user' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction={'start_timestamp': 1763223971.27717, 'end_timestamp': 1763223980.364303, 'compacted_content': {'parts': [{'function_call': None, 'code_execution_result': None, 'executable_code': None, 'file_data': None, 'function_response': None, 'inline_data': None, 'text': 'This conversation history demonstrates an exchange between a user seeking information about AI in healthcare and an AI agent providing detailed summaries.\n\n**Key Information and Decisions:**\n\n*   **User\'s Initial Query:** The user asked for the "latest news about AI in healthcare."\n*   **AI\'s Comprehensive Overview:** The AI agent provided a broad overview of AI advancements in healthcare, covering areas like:\n    *   Drug Discovery and Development\n    *   Medical Imaging and Diagnostics\n    *   Personalized Medicine\n    *   Robotics and Surgery\n    *   Virtual Assistants\n    *   Administrative Efficiency\n    *   Emerging Trends (Generative AI, XAI) and Challenges (data privacy, bias, regulation).\n*   **User\'s Follow-up Query:** The user then specifically requested more information on the "second development" mentioned, which was "Revolutionizing Molecule Design and Optimization" in drug discovery.\n*   **AI\'s In-depth Explanation:** The AI agent provided a detailed explanation of how AI is revolutionizing molecule design and optimization, focusing on:\n    *   The traditional challenges of drug discovery (time, cost, limited scope).\n    *   How generative AI is used for **de novo drug design**, creating novel molecular structures with desired properties.\n    *   The role of AI in **lead optimization**, refining existing compounds for better efficacy and safety (ADMET properties).\n    *   The emerging synergy between **quantum computing and AI** for molecular simulation.\n\n**Unresolved Questions or Tasks:**\n\nThere are no explicit unresolved questions or tasks from the user\'s perspective. The conversation has been a direct information exchange where the AI has successfully addressed the user\'s inquiries with detailed and relevant information. The user did not indicate any further questions or need for action.', 'thought': None, 'thought_signature': None, 'video_metadata': None}], 'role': 'model'}}, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=set() branch=None id='97b5da61-69e7-4f07-a165-9f883c53acee' timestamp=1763223987.954968

# %%
# Define scope levels for state keys (following best practices)
USER_NAME_SCOPE_LEVELS = ("temp", "user", "app")


# This demonstrates how tools can write to session state using tool_context.
# The 'user:' prefix indicates this is user-specific data.
def save_userinfo(
    tool_context: ToolContext, user_name: str, country: str
) -> Dict[str, Any]:
    """
    Tool to record and save user name and country in session state.

    Args:
        user_name: The username to store in session state
        country: The name of the user's country
    """
    # Write to session state using the 'user:' prefix for user data
    tool_context.state["user:name"] = user_name
    tool_context.state["user:country"] = country

    return {"status": "success"}


# This demonstrates how tools can read from session state.
def retrieve_userinfo(tool_context: ToolContext) -> Dict[str, Any]:
    """
    Tool to retrieve user name and country from session state.
    """
    # Read from session state
    user_name = tool_context.state.get("user:name", "Username not found")
    country = tool_context.state.get("user:country", "Country not found")

    return {"status": "success", "user_name": user_name, "country": country}


print("✅ Tools created.")
# Out:
# ✅ Tools created.

# %%
# Configuration
APP_NAME = "default"
USER_ID = "default"
MODEL_NAME = "gemini-2.5-flash-lite"

# Create an agent with session state tools
root_agent = LlmAgent(
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    name="text_chat_bot",
    description="""A text chatbot.
    Tools for managing user context:
    * To record username and country when provided use `save_userinfo` tool.
    * To fetch username and country when required use `retrieve_userinfo` tool.
    """,
    tools=[save_userinfo, retrieve_userinfo],  # Provide the tools to the agent
)

# Set up session service and runner
session_service = InMemorySessionService()
runner = Runner(agent=root_agent, session_service=session_service, app_name="default")

print("✅ Agent with session state tools initialized!")
# Out:
# ✅ Agent with session state tools initialized!

# %%
# Test conversation demonstrating session state
await run_session(
    runner,
    [
        "Hi there, how are you doing today? What is my name?",  # Agent shouldn't know the name yet
        "My name is Sam. I'm from Poland.",  # Provide name - agent should save it
        "What is my name? Which country am I from?",  # Agent should recall from session state
    ],
    "state-demo-session",
)
# Out:
#  ### Session: state-demo-session
#
# User > Hi there, how are you doing today? What is my name?
# gemini-2.5-flash-lite >  Hello! I'm doing well, thank you for asking. I can't recall your name at the moment. Can you please tell me what it is?
#
# User > My name is Sam. I'm from Poland.
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# gemini-2.5-flash-lite >  It's a pleasure to meet you, Sam! I'll save your name and country.
# gemini-2.5-flash-lite >  Hello Sam! It's nice to meet you. I have saved your name and country. How can I help you further?
#
# User > What is my name? Which country am I from?
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# gemini-2.5-flash-lite >  Your name is Sam and you are from Poland.

# %%
# Retrieve the session and inspect its state
session = await session_service.get_session(
    app_name=APP_NAME, user_id=USER_ID, session_id="state-demo-session"
)

print("Session State Contents:")
print(session.state)
print("\n🔍 Notice the 'user:name' and 'user:country' keys storing our data!")
# Out:
# Session State Contents:
# {'user:name': 'Sam', 'user:country': 'Poland'}
#
# 🔍 Notice the 'user:name' and 'user:country' keys storing our data!

# %%
# Start a completely new session - the agent won't know our name
await run_session(
    runner,
    ["Hi there, how are you doing today? What is my name?"],
    "new-isolated-session",
)

# Expected: The agent won't know the name because this is a different session
# Out:
#  ### Session: new-isolated-session
#
# User > Hi there, how are you doing today? What is my name?
# gemini-2.5-flash-lite >  Hello! I'm doing great. I'd love to tell you your name, but I don't have that information stored. Can you tell me what it is? Or, if you've told me before, I can try to look it up.

# %%
# Check the state of the new session
session = await session_service.get_session(
    app_name=APP_NAME, user_id=USER_ID, session_id="new-isolated-session"
)

print("New Session State:")
print(session.state)

# Note: Depending on implementation, you might see shared state here.
# This is where the distinction between session-specific and user-specific state becomes important.
# Out:
# New Session State:
# {'user:name': 'Sam', 'user:country': 'Poland'}

# %%
# Clean up any existing database to start fresh (if Notebook is restarted)
import os

if os.path.exists("my_agent_data.db"):
    os.remove("my_agent_dataac.db")
print("✅ Cleaned up old database files")
