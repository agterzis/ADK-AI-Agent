# %% [markdown]
# <a href="https://colab.research.google.com/github/agterzis/ADK-AI-Agent/blob/main/From_Prompt_to_Action.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-adk==1.18.0

# %%
import os
from google.colab import userdata
import google.generativeai as genai

try:
    GOOGLE_API_KEY = userdata.get("GOOGLE_API_KEY")
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY # Set as environment variable
    genai.configure(api_key=GOOGLE_API_KEY) # Configure google.generativeai globally
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print(
        f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Colab secrets. Details: {e}"
    )
# Out:
# ✅ Gemini API key setup complete.

# %%
from google.adk.agents import Agent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import google_search
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1, # Initial delay before first retry (in seconds)
    http_status_codes=[429, 500, 503, 504] # Retry on these HTTP errors
)

# %%
root_agent = Agent(
    name="helpful_assistant",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
        # api_key=GOOGLE_API_KEY # API key now configured globally
    ),
    description="A simple agent that can answer general questions.",
    instruction="You are a helpful assistant. Use Google Search for current info or if unsure.",
    tools=[google_search],
)

print("✅ Root Agent defined.")
# Out:
# ✅ Root Agent defined.

# %%
runner = InMemoryRunner(agent=root_agent)

print("✅ Runner created.")
# Out:
# ✅ Runner created.

# %%
response = await runner.run_debug(
    "What is Agent Development Kit from Google? What languages is the SDK available in?"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > What is Agent Development Kit from Google? What languages is the SDK available in?
# helpful_assistant > **Google's Agent Development Kit (ADK)**
#
# Google's Agent Development Kit (ADK) is an open-source, modular framework designed to simplify the development, deployment, and orchestration of AI agents and multi-agent systems. It aims to bring software development principles to AI agent creation, allowing for more robust debugging, versioning, and deployment. The ADK is optimized for Google's Gemini models and the Google Cloud ecosystem but is designed to be model-agnostic and compatible with other frameworks.
#
# Key features of the ADK include:
# *   **Flexible Orchestration:** Define agent workflows using sequential, parallel, or loop agents, or leverage LLM-driven dynamic routing.
# *   **Multi-Agent Architecture:** Build scalable applications by composing multiple specialized agents in a hierarchy.
# ...

# %%
response = await runner.run_debug("What's the weather in Thessaloniki?")
# Out:
#  ### Continue session: debug_session_id
#
# User > What's the weather in Thessaloniki?
# helpful_assistant > The weather in Thessaloniki, Greece is currently mostly sunny with a temperature of 63°F (17°C). The humidity is around 67%.
#
# The forecast for today predicts sunny conditions during the day and partly cloudy at night, with a 5% chance of rain. The temperature is expected to range between 42°F (6°C) and 63°F (17°C).
